# %% [markdown]
# # Sistemas de Apoio à Decisão
# ## Perguntas teóricas
# ### 2018/19
# ---
#
# Todas as perguntas teóricas têm respostas explícitas nos slides/apontamentos ou no livro.
#
# Qualquer questão entrem em contacto comigo (nbras@autonoma.pt)
#
# Bom Trabalho
#
# ----
#
# #### Introdução
#
# 1) Defina Datawarehouse
#
# ---
#
# 2) Distinga a Abordagem Clássica de Novas Abordagens ao Datawarehouse
#
# ---
#
# 3) O que é um processo de ETL (Extraction, Transformation and Loading) de Dados?
#
# ---
#
# 4) Como se distinguem os mecanismos de ELT - Extract, Load and Transform dos mecanismos de ETL (Extraction, Transformation and Loading)?
#
# Quais são os mais actuais e porquê?
#
# ---
#
# 5) O que é Data Mining
#
#
# ---
# 6) Imagine que temos uma empresa XPTO de produtos de Telecomunicações. Dos grupos de actividades apresentadas, descreva em que medida são ou não problemas de DataMining ou simplemsmente soluções analítcas de dados (como agregações ou queries).
# - Procurar clientes pelo seu Nif numa base de dados
# - Procurar clientes empresa que comprariam um produto premium tendo em conta a idade da empresa, localidade e dinheiro gasto anteriormente com produtos XPTO
# - Procurar os 10 clientes que mais gastaram dinheiro com produtos XPTO durante o verão;
# - Perceber que produtos devemos sugerir para aquisição na pagina www de cada produto, de forma a maximizar as vendas
# - Procurar o conjunto de clientes optimos para uma campanha, a partir dos dados históricos de campanhas anteriores
# - Posicionar os produtos no armazem logistico de forma a que a recolha e distribuição dos produtos seja simplificada
# - Perceber qual o intervalo de idades (de 5 em 5 anos) que mais produtos XPTO comprou no último ano, tendo em conta somente aparelhos de Wifi
# - Que produtos XPTO tiveram mais primeiras avarias, considerando os registos de devoluções dos 2 meses seguintes às compras;
#
#
# ---
#
# 7) Distinga Regressão e Classificação na área de Machine Learning
#
# ---
#
# 8) Distinga classificadores supervisionados de não supervisionados e dê exemplos
#
# ---
#
# 9) Dentro de um modelo de Classificação defina o que são os seguintes componentes
# - Features
# - Classes
# - Dataset
#
# ---
#
#
# 10) Defina:
# - Clustering
# - Association Rule Discovery
# - Regression
# - Classification
#
# ---
#
# 11) Dê exemplos concretos de situações onde cada uma das áreas anteriores (pergunta 10) podem fazer diferença.
#
# ---
#
# 12) Explique em que medida um dataset pode ser visto como uma nuvem de vectores? O que tem a dimensionalidade de um dataset?
#
# ---
#
# #### Preprocessing
#
# ---
#
# 13) Dê exemplos e defina, dizendo em que situações faz sentido aplicar cada uma das técnicas referidas:
#
# - Binarização
# - Discretização
# - Normalização
# - Encoding (One Hot Encoding)
#
#
# ----
#
# 14) Explique como deve ser feita a validação dos resultados de um algoritmo. Refira-se nomeadamente a métodos de medir a sua performance antes de se usar em casos reais;
#
# ----
#
# 15) Para que serve o Test Set e o Training Set? Qual deve ser maior?
#
# ----
#
# 16) Após o treino de um modelo, podemos caracterizar genericamente o seu resultado com Overfitting, adequado e Underfitting.  Defina cada um desses cenários.
#
# <img src="images/overfitting_underfitting.png"   style="width:60%"/>
#
# Ohando para estas imagens qual deles é qual? E porque?
#
# ----
#
# 17) Qual a diferença entre Random Sampling e Stratified Sampling? Em que alturas deve utilizar uma ou outra.
#
# ----
#
# #### Regressão Linear
#
# ----
#
# 18) A seguinte expressão que traduz o problema da regressão linear
#
# $$\hat{w} = \underset{w}{\text{min}} \space\space \frac{1}{2}\sum_i^N{(w_0 + w_1x_i-y_i)^2}$$
#
#
# $$\hat{w} = \underset{w}{\text{min}} \space\space \frac{1}{2}\sum_i^N{(w_0 + w_1x_i + w_2x_i^2 + w_3x_i^3 -y_i)^2}$$
#
# em que os w são os parâmetros e os y são os targets;
#
# - Explique o que quer dizer esta expressão
# - Explique apenas por palavras como é que a partir desta expressão se determinam os parâmetros w óptimos de forma fechada (sem iterações).
#
#
# ----
#
# 19) Explique por palavras suas o que faz a regressão Linear com e que solução este estimador nos dá (ou seja, o que são os parâmetros $\hat{w}_i$ encontrados)
#
# #### Regressao Logistica
#
# ----
#
# 20) Explique por palavras suas o que faz a regressão Logística e que solução este estimador nos dá (ou seja, o que são os parâmetros encontrados)
#
# ----
#
# 21) Responda e comente os seguintes pontos:
#
# - Sendo a regressão linear um processo de fit linear, como se explica que possa ser aplicado a funções não lineares como polinómios?
# - O modelo Logistic Regression não é linear em relação aos parâmetros do modelo ($w$). Porque?
# - A Logistic Regression não tem uma solução fechada para os parâmetros óptimos. Como é então feita a aproximação do minimo da função de custo no caso da Logistic Regression?
#
# ----
#
# 22) O Gradient Descent é dado pela seguinte expressão:
#
# $$ w_{t+1}=w_{t} - \mu \nabla_w{Cost}$$
#
# Considerando esta expressão responda:
# - Explique como funciona o gradient descent;
# - Explique como esta técnica se aplica ao cálculo da logitic Regression;
#
# #### Decision Trees
#
# ----
#
# 23) Explique por palavras suas como funciona o Classificador Decision Tree e como deve ser usada a árvore resultante. A solução resultante é óptima?
#
# ----
#
# 24) Quais as vantagens e desvantagens de um classificador do tipo Decision Tree?
#
# #### Random Forrest
#
# ----
#
#
# 25) O que é um Ensemble Method - Explique porque é que se diz que o Random Forrest é um Ensemble method?
#
# ----
#
# 26) Explique por palavras suas como funciona o Classificador Random Forrest e como funciona. Qual o problema principal que o Random Forrest vem resolver, face ao classificador Decision Tree?
#
# ----
#
# 27) Porque se costuma dizer que o Random Forrest é um excelente método para iniciar um processo de classificação?
#
# ----
#
# 28) O que se perde ao usar Random Forrest em vez de uma Decision Tree?
#
# #### Naive Bayes
#
# ----
#
# 29) Explique a diferença entre Algoritmos Discriminativos e Algoritmos Generativos;
#
# ----
#
# 30) Porque razão se chama Naive ao método de Naive Bayes?
#
#
# #### Knn
#
# ----
#
# 31) No k-Nearest-Neighbor explique o que são :
# - O Valor de k
# - A Métrica de distância usada
# - Porque se diz que o método pode ser pesado quando aplicado, comparativamente com outros?
#
# ----
#
#
# 32) No KNN, Considere $w$ como um peso para os diversos $k$ registos dado por $w=1/d^2$. Explique para que serve e que vantagens tem usar este peso na classificação em vez do valor $d$ da distância entre o ponto e os $k$ registos;
#
# #### Association Rules
#
# 33) Defina Suporte e confiança de uma regra de associação;
#
# ----
#
# 34) Explique como funciona o método **à priori** para a escolha dos conjuntos de items mais frequentes.
#
# ----
#
# 35) Como pode, posteriormente, determinar quais as regras elegíveis?
#
# ----
